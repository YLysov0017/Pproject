# %% [markdown]
# <a href="https://colab.research.google.com/github/YLysov0017/Pproject/blob/master/IIS_task1_Lysov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ИИС - Задание 1, Вариант №53

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = np.array([[ 4.06862817, 5.65143303],
 [ 0.28566948, 6.15080519],
 [18.96191779,20.97435219],
 [ 7.47025486, 1.28619121],
 [18.82318364,20.33041478],
 [12.74272459,10.77526927],
 [12.73783278, 8.37174629],
 [ 1.7861078 , 6.22975279],
 [21.17457326,16.8461289 ],
 [17.21694767,17.29741577],
 [12.65183807,10.52108452],
 [20.15820272,15.84984491],
 [21.79493533,16.15235561],
 [12.81894894, 6.83125738],
 [19.77728405,15.88419247],
 [ 7.76413836, 0.93831447],
 [20.73834599,15.910502 ],
 [ 7.27746927, 0.7196397 ],
 [12.82997215,12.78901709],
 [12.48235776, 9.54050997],
 [11.78971457, 9.02121329],
 [12.66767773,12.65615208],
 [ 2.37888126, 5.83304913],
 [13.27648498,10.75455707],
 [ 8.25943012, 1.90189554],
 [ 0.47880094, 5.72091809],
 [ 0.75823137, 4.87270697],
 [ 7.66447064, 1.5820944 ],
 [ 6.63788947, 0.66622021],
 [ 7.99491597, 1.53582632],
 [13.04135907, 9.33528871],
 [17.25056871,17.74790678],
 [ 2.16998297, 6.79580514],
 [22.05296729,16.44973563],
 [ 7.48322114, 0.45304823],
 [ 7.52762937, 1.00463058],
 [20.09266063,16.63830525],
 [18.41367124,17.63623363],
 [ 7.24011894, 0.8894556 ],
 [ 7.67626638, 0.74472799],
 [ 1.87056179, 6.36411128],
 [22.0569224 ,15.33537353],
 [ 2.39571916, 5.03046969],
 [ 7.24494471, 0.17575503],
 [ 0.94309924, 6.32682124],
 [13.3533457 ,11.19552927],
 [17.6463541 ,18.53975804],
 [12.09708732,10.76500138],
 [12.67051421, 9.233864 ],
 [ 2.14872397, 5.73402454],
 [ 7.3264472 , 1.18486361],
 [ 1.57850917, 5.64870692],
 [ 0.79925699, 6.23196994],
 [ 8.89552282, 1.0134367 ],
 [13.55842539,12.25374628],
 [ 2.45550882, 5.69123728]])

# %%
# список для сохранения значений инерции (сумма квадратов расстояний от точек до ближ. центроидов)
inertia_values = []
# Перебираем количество кластеров
for k in range(2, 11):
 # объект KMeans с текущим количеством кластеров
 kmeans = KMeans( n_clusters = k)
 kmeans.fit( data )
 # Сохраняем значение инерции - мерой компактности кластеров.
 # Он вычисляется как сумма квадратов расстояний между каждым объектом данных и центроидом
 inertia_values.append( kmeans.inertia_ )

plt.plot(range(2, 11), inertia_values, marker='o')
plt.xlabel("Количество кластеров")
plt.ylabel("Сумма квадратов расстояний")
plt.title("Метод локтя")
plt.show()

# %% [markdown]
# *Сумма квадратов расстояний перестает существенно меняться при числе кластеров больше 4. 4 кластера можно считать достаточным.*

# %%
kmeans = KMeans( n_clusters = 4 )
# Производим кластеризацию данных
kmeans.fit( data )
# метки кластеров для каждого объекта
labels = kmeans.labels_
# координаты центроидов
centroids = kmeans.cluster_centers_
print("Метки кластеров:")
print(labels)
print("Координаты центроидов кластеров:")
print(centroids)
labelNum = np.unique(labels)
for v in labelNum:
 print(f"В кластере с меткой {v} содержится {np.sum(labels == v)} точек" )
plt.scatter(data[:,0], data[:,1], c = labels )
plt.scatter(centroids[:,0], centroids[:,1], c = "r")
plt.show()
# Out:
# Метки кластеров:
# [1 1 2 3 2 0 0 1 2 2 0 2 2 0 2 3 2 3 0 0 0 0 1 0 3 1 1 3 3 3 0 2 1 2 3 3 2
#  2 3 3 1 2 1 3 1 0 2 0 0 1 3 1 1 3 0 1]
# Координаты центроидов кластеров:
# [[12.76559166 10.28887404]
#  [ 1.72269151  5.87727223]
#  [19.72560963 17.25660853]
#  [ 7.60447995  1.00686426]]
# В кластере с меткой 0 содержится 14 точек
# В кластере с меткой 1 содержится 14 точек
# В кластере с меткой 2 содержится 14 точек
# В кластере с меткой 3 содержится 14 точек

# %% [markdown]
# ## Кластеризация с random_state

# %% [markdown]
# ### 1

# %%
kmeans = KMeans( n_clusters = 4, random_state=10 )
# Производим кластеризацию данных
kmeans.fit( data )
# метки кластеров для каждого объекта
labels = kmeans.labels_
# координаты центроидов
centroids = kmeans.cluster_centers_
print("Метки кластеров:")
print(labels)
print("Координаты центроидов кластеров:")
print(centroids)
labelNum = np.unique(labels)
for v in labelNum:
 print(f"В кластере с меткой {v} содержится {np.sum(labels == v)} точек" )
plt.scatter(data[:,0], data[:,1], c = labels )
plt.scatter(centroids[:,0], centroids[:,1], c = "r")
plt.show()
# Out:
# Метки кластеров:
# [3 3 1 0 1 2 2 3 1 1 2 1 1 2 1 0 1 0 2 2 2 2 3 2 0 3 3 0 0 0 2 1 3 1 0 0 1
#  1 0 0 3 1 3 0 3 2 1 2 2 3 0 3 3 0 2 3]
# Координаты центроидов кластеров:
# [[ 7.60447995  1.00686426]
#  [19.72560963 17.25660853]
#  [12.76559166 10.28887404]
#  [ 1.72269151  5.87727223]]
# В кластере с меткой 0 содержится 14 точек
# В кластере с меткой 1 содержится 14 точек
# В кластере с меткой 2 содержится 14 точек
# В кластере с меткой 3 содержится 14 точек

# %% [markdown]
# ### 2

# %%
kmeans = KMeans( n_clusters = 4, random_state=122435 )
# Производим кластеризацию данных
kmeans.fit( data )
# метки кластеров для каждого объекта
labels = kmeans.labels_
# координаты центроидов
centroids = kmeans.cluster_centers_
print("Метки кластеров:")
print(labels)
print("Координаты центроидов кластеров:")
print(centroids)
labelNum = np.unique(labels)
for v in labelNum:
 print(f"В кластере с меткой {v} содержится {np.sum(labels == v)} точек" )
plt.scatter(data[:,0], data[:,1], c = labels )
plt.scatter(centroids[:,0], centroids[:,1], c = "r")
plt.show()
# Out:
# Метки кластеров:
# [2 2 1 0 1 3 3 2 1 1 3 1 1 3 1 0 1 0 3 3 3 3 2 3 0 2 2 0 0 0 3 1 2 1 0 0 1
#  1 0 0 2 1 2 0 2 3 1 3 3 2 0 2 2 0 3 2]
# Координаты центроидов кластеров:
# [[ 7.60447995  1.00686426]
#  [19.72560963 17.25660853]
#  [ 1.72269151  5.87727223]
#  [12.76559166 10.28887404]]
# В кластере с меткой 0 содержится 14 точек
# В кластере с меткой 1 содержится 14 точек
# В кластере с меткой 2 содержится 14 точек
# В кластере с меткой 3 содержится 14 точек

# %% [markdown]
# ### 3

# %%
from numpy.random import RandomState
kmeans = KMeans( n_clusters = 4, random_state=RandomState(131242) )
# Производим кластеризацию данных
kmeans.fit( data )
# метки кластеров для каждого объекта
labels = kmeans.labels_
# координаты центроидов
centroids = kmeans.cluster_centers_
print("Метки кластеров:")
print(labels)
print("Координаты центроидов кластеров:")
print(centroids)
labelNum = np.unique(labels)
for v in labelNum:
 print(f"В кластере с меткой {v} содержится {np.sum(labels == v)} точек" )
plt.scatter(data[:,0], data[:,1], c = labels )
plt.scatter(centroids[:,0], centroids[:,1], c = "r")
plt.show()
# Out:
# Метки кластеров:
# [0 0 1 3 1 2 2 0 1 1 2 1 1 2 1 3 1 3 2 2 2 2 0 2 3 0 0 3 3 3 2 1 0 1 3 3 1
#  1 3 3 0 1 0 3 0 2 1 2 2 0 3 0 0 3 2 0]
# Координаты центроидов кластеров:
# [[ 1.72269151  5.87727223]
#  [19.72560963 17.25660853]
#  [12.76559166 10.28887404]
#  [ 7.60447995  1.00686426]]
# В кластере с меткой 0 содержится 14 точек
# В кластере с меткой 1 содержится 14 точек
# В кластере с меткой 2 содержится 14 точек
# В кластере с меткой 3 содержится 14 точек
